# %%
import pandas as pd
import csv
import random
import re

# %% [markdown]
# ### 1. Verilerin Yüklenmesi
#
# 7000 veriden oluşan ve hastalık tahmininde kullandığımız veri kombinasyon dosyasını yüklüyoruz. Bu dosya değişik semptom kombinasyonlarından oluşup bu notebook'ta rasa için uygun eğitim verisi oluşturmakta kullanılacaktır.
#
# Chatbot'un zeki olarak nitelendirilebilmesi için cümlede çeşitli varlıkları (entity) tespit edebilmesi gerekmektedir.
#
# Örneğin benim bugün başım ağrıyor, ateşim var, boğazım şişti ve burnum akıyor cümlesinde RASA'nın her bir semptomu (baş ağrısı, ateş, şiş boğaz ve burun akıntısı) tespit edebilmesi gerekmektedir.
#
# Eğitim verisi formatı şu şekildedir:
#
# ```
# Benim bugün [başım ağrıyor] (semptom), [ateşim] (semptom) var, [boğazım şişti] (semptom) ve [bulanık görüyorum] (semptom)
# ```
#
# Ayrıca eğitim verisi içinde görüşün netliğini belirtirken yalnızca bulanık görüyorum değil görüşüm net değil gibi aynı anlamı taşıyan ama farklı şekilde söylenmiş semptomlar da bulunmalıdır.

# %%
veri_komb = pd.read_csv('veri_komb.csv', encoding='iso-8859-9', sep=",")
veri_komb.set_index('hastalik').head()
# Out:
#           baş ağrısı  bulanık görme  burun kanaması  düzensiz kalp ritmi  \
# hastalik
# addison            0              0               0                    0
# addison            0              0               0                    0
# addison            0              0               0                    0
# addison            0              0               0                    0
# addison            0              0               0                    0
#
#           göğüs ağrısı  göğüste baskı  idrarda kan  nefes darlığı  \
# hastalik
# addison              0              0            0              0
# addison              0              0            0              0
# addison              0              0            0              0
# addison              0              0            0              0
# addison              0              0            0              0
#
#           ciltte kırmızlık  kaşıntı  ...  öğün atlamak  şiş boğaz  \
# hastalik                             ...
# addison                  0        0  ...             0          0
# addison                  0        0  ...             0          0
# addison                  0        0  ...             0          0
# addison                  0        0  ...             0          0
# addison                  0        0  ...             0          0
#
#           hafıza kaybı  ruh hali değişimleri  kanlı balgam  ağız içinde yumru  \
# hastalik
# addison              0                     0             0                  0
# addison              0                     0             0                  0
# addison              0                     0             0                  0
# addison              0                     0             0                  0
# addison              0                     0             0                  0
#
#           ağızda uyuşma  gevşek diş  iyileşmeyen ağız yarası  koyu cilt
# hastalik
# addison               0           0                        0          0
# addison               0           0                        0          0
# addison               0           0                        0          1
# addison               0           0                        0          0
# addison               0           0                        0          1
#
# [5 rows x 199 columns]

# %% [markdown]
# Kişilerin yaşadıkları semptomları çok farklı şekillerde ifade edebilirler.
#
# Örneğin zayıfladıklarını aşağıdaki şekillerde ifade edebilirler.
# - zayıfladım
# - kilom azaldı
# - kilomda azalış oldu
# - semptomlarım arasında kilo azalışı var
# - semptomlarım zayıflama
#
# Ya da konuşmakta güçlük çektikilerini aşağıdaki gibi ifade edebilirler.
# - konuşmakta güçlük çekiyorum
# - konuşmakta zorlanıyorum
# - dil becerilerimde kayıp var
#
# Dilin bu özelliğini RASA'da synonym mapper ile telafi edebiliyoruz. Synonym mapper aşağıdaki formatta olup içerdiği veriler RASA'nın nlu.yml dosyasında bulunmaktadır. Biz de bu formata uygun semptom ve benzer söylenişlerini düzenleyip synonyms.txt dosyasına kaydediyoruz.
#
# - synonym: nefes darlığı
#
#   examples: |
#     - nefesim daralıyor
#     - solunum sıkıntısı
#     - nefes almakta güçlük
#     - nefes almakta zorluk

# %%
my_dict = {}

with open('semptomlar.csv', newline='',  encoding='iso-8859-9') as f_input:
    csv_input = csv.reader(f_input, delimiter=';')
    header = next(csv_input)   # skip over the header row

    for row in csv_input:
        my_dict[row[0]] = [cell for cell in row[1:] if cell]

print(my_dict)
# Out:
# {'açlık': ['aç'], 'açlık reddi': ['açlığımı reddediyorum'], 'ağız içinde yumru': ['ağzımda yumru', 'ağzımda kitle'], 'ağız kokusu': ['ağzım kokuyor', 'ağzımda koku var'], 'ağızda aseton kokusu': ['ağzımda aseton kokusu', 'ağzımda aseton tadı'], 'ağızda köpük': ['ağzımdan köpük'], 'ağızda uyuşma': ['ağzım uyuşuyor', 'ağzımda uyuşukluk'], 'ağrısız yara': ['yaralarım ağrımıyor'], 'akciğer sıvısı': ['akciğerimde sıvı'], 'akne': ['sivilce'], 'alt karın ağrısı': ['karnımın alt bölgesi ağrıyor', 'karnımın alt bölgesinde ağrı'], 'artan gözyaşı': ['gözyaşımda artış', 'gözlerimde yaş'], 'asimetrik ben': ['benimde asimetri '], 'ateş': ['ateşim'], 'ayakların istemsiz dönmesi': ['ayaklarımda istemsiz hareket', 'ayağımda istemsiz hareket'], 'bacak ağrısı': ['bacağım ağrıyor', 'bacaklarımda ağrı'], 'bağırsak tıkanması': ['tıkanmış bağırsaklar'], 'balgam': ['balgamım'], 'baş ağrısı': ['başım ağrıyor', 'başımda ağrı'], 'baş dönmesi': ['başım dönüyor'], 'bayılma': ['bayıldım'], 'bel ağrısı': ['belim ağrıyor'], 'ben kanaması': ['benlerim kanıyor', 'benim kanıyor'], 'ben sayısında artış ': ['benlerim arttı'], 'bilinç bulanıklığı': ['bilincim açık değil', 'bulanık bilinç', 'bilincim bulanık'], 'boğaz ağrısı': ['boğazım ağrıyor', 'boğazımda ağrı'], 'boğazda yanma': ['boğazım yanıyor', 'boğazımda yanma hissi'], 'boyda kısalma': ['boyum kısaldı'], 'boynun istemsiz dönmesi ': ['boynum istemsiz dönüyor'], 'boyunda yumru': ['boynumda kitle', 'boynumda sertlik', 'boyun kitlesi'], 'böbrek yetmezliği': ['böbrek yetersizliği'], 'böbrekte yumru': ['böbreklerde kitle', 'böbrekte kitle'], 'bulanık görme': ['bulanık görüyorum', 'görüşüm net değil'], 'bulantı': ['midem bulanıyor', 'bulantım'], 'burun akıntısı': ['burnum akıyor'], 'burun kanaması': ['burnum kanıyor'], 'burunda mukus': ['burnumda mukus', 'burnumda salgı'], 'ciltte döküntü': ['cildim dökülüyor', 'cildimde döküntüler', 'derimde döküntüler'], 'ciltte kabarcık': ['cildimde kabarcık'], 'ciltte kaşıntı': ['cildim kaşınıyor'], 'ciltte kırmızlık': ['kırmızı cilt', 'cildimde kırmızılık'], 'ciltte kuruluk': ['kuru cilt', 'cildimde kuruluk', 'kuru bir cilt'], 'ciltte mavilik': ['cildimde mavilik', 'cildim mavi', 'mavi cilt'], 'ciltte sarılık': ['sarı cilt'], 'ciltte yanma': ['cildim yanıyor'], 'çıban': ['apse'], 'çınlama': ['kulak çınlaması'], 'çift görme': ['çift görüyorum'], 'deride su toplanması': ['derimde su kabarcığı', 'deride su kabarcığı', 'derimde su kabarcıkları'], 'dışkı rengide değişiklik': ['dışkım farklı renkte', 'dışkımın rengi farklı'], 'dışkıda kan': ['dışkımda kan'], 'diş kenetlenme': ['dişlerim kenetleniyor'], 'dişlerde çürüme': ['çürüyor', 'çürüklerim', 'çürüğüm'], 'diz ağrısı': ['dizlerim ağrıyor', 'dizimde ağrı'], 'diz kilitlenmesi': ['dizlerim kitlendi'], 'dizde çıtlama sesi': ['dizimde çıtlama'], 'donuk bakış': ['bakışlarda donukluk', 'dalgınlık', 'dalgın bakışlar', 'bakışlarda dalgınlık'], 'duyu kaybı': ['duyularımda kayıp'], 'düşük kan basıncı': ['kan basıncım düşük'], 'düşük tansiyon': ['tansiyonum düştü'], 'düzensiz kalp ritmi': ['kalbim düzensiz atıyor', 'kalp atışımda düzensizlik', 'çarpıntı', 'aritmi'], 'eklem ağrısı': ['eklemlerim ağrıyor'], 'eklem boşalması': ['eklemlerde boşalma', 'eklemlerim boşaldı'], 'ense ağrısı': ['ensemde ağrı', 'ensem ağrıyor'], 'felç': ['inme'], 'gaz': ['gazım '], 'gece görüşünde düşüş': ['gece görüşünde kayıp'], 'gevşek diş': ['dişlerim gevşek', 'dişim gevşek'], 'göğüs ağrısı': ['göğsüm ağrıyor'], 'göğüste baskı': ['göğsümde baskı', 'göğsümde sıkışıklık'], 'görme kaybı': ['görmede zorluk'], 'göz çevresinde basınç': ['gözlerimde basınç', 'göz basıncı'], 'göz kararması': ['gözlerimde karartı'], 'göz kaşıntısı': ['gözlerim kaşınıyor'], 'gözde kızarıklık': ['gözümde kızarma', 'gözüm kızardı'], 'gözde kitle': ['gözümde kitle'], 'gözlerin ani ve aşırı kırpılması': ['gözlerim çok kırpışıyor', 'gözlerimde ani kırpılmalar'], 'gündüz uyku hali': ['uykuluyum', 'uykum'], 'hafıza kaybı': ['hafızamda kayıp'], 'halüsinasyon': ['sanrı', 'sanrılar'], 'hapşırma': ['h ...

# %%
with open("synonyms.txt", "a") as f:
  for x, y in my_dict.items():
    print(f"- synonym: {x}" + "\n" + "  " + "examples: |", file=f)
    for i in y:
      print(f"    " + "- " + i, file=f)
    print("\n", file=f)

# %% [markdown]
# ### 2. Rasa için Eğitim Verisinin Hazırlanması

# %%
semptom_sayisi = [1, 2, 3, 4]
cumle_baslangici = [
    "Benim",
    "Kötü hissediyorum. Benim",
    "Çok kötü bir",
    "Semptomlarım",
    "Son birkaç gündür benim",
    "Oğlum son birkaç gündür" ,
    "Dün çok kötü bir",
    "Kızım çok kötü hissediyor. Kızımın",
    "Çocuğum iyi hissetmiyor. Onun",
    "İyi hissetmiyorum. Benim",
    "Çok kötüyüm."
]

# %%
with open("synonyms.txt", "a") as f:
  for x, y in my_dict.items():
    print(f"- synonym: {x}" + "\n" + "  " + "examples: |", file=f)
    for i in y:
      print(f"    " + "- " + i, file=f)
    print("\n", file=f)

# %%
for sayi in semptom_sayisi:
    
    for ornek in range(1, 500):
      
      with open("semptom_ornek.txt", "a") as f:
    
        baslangic = random.choice(cumle_baslangici)
        semptomlar = []

        for i in range(len(semptom_sayisi)):

          # collect some random symtpoms
          random_list = []
          random_symptom = random.choice(list(my_dict.keys()))
          # append symptom 
          random_list.append(random_symptom) 
          # or append synoym of that symptom
          random_list.append(random.choice(my_dict[random_symptom]))

          semptom = random.choice(random_list)
          semptomlar.append(semptom)

        semptom_rasa = []
        
        for semptom in semptomlar:
            semptom = f"[{semptom}](semptom)"
            semptom_rasa.append(semptom)
            
        semptom_1 = semptom_rasa[0]
        semptom_2 = semptom_rasa[1]
        semptom_3 = semptom_rasa[2]
        semptom_4 = semptom_rasa[3]

        if sayi == 1:
            
            ornek_veri = f"- {baslangic} {semptom_1}"
            
        if sayi == 2:
            
            ornek_veri = f"- {baslangic} {semptom_1} ve {semptom_2}"
            
            
        if sayi == 3:
            
            ornek_veri = f"- {baslangic} {semptom_1}, {semptom_2}, ve {semptom_3}"
            
            
        if sayi == 4:
            
            ornek_veri = f"- {baslangic} {semptom_1}, {semptom_2}, {semptom_3}, {semptom_4}"

        print(ornek_veri, file=f)

# %% [markdown]
# ### Ek: Semptom isimlerinin elde edilmesi
#
# Synonym mapper yapabilmek için her semptomun olduğu bir dosyaya ihtiyacımız vardı.

# %%
semptomlar_df = pd.DataFrame(veri_komb.columns, columns=["semptom"])

# %%
semptomlar_df.to_csv('semptomlar.csv', encoding='ISO-8859-9', index=False)
